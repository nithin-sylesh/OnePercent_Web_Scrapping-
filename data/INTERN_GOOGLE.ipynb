# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

plt.style.use('bmh')

# %%
df = pd.read_csv('C://Users//NITHIN SYLESH//Documents//int//onepercent//New folder//CSV Files//DIGITAL_MARKETING_PLATFORM_INTERN_GOOGLE.csv')
df.head()
# Out:
#    INTERN  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
# 0       7         6          4        4      0         2       2         2
# 1       9       120          2        0      0         3       2         1
# 2      10         0          0        0      0         0       0         0
# 3      15         0         48      294      0        10      76        26
# 4      18       840        186        0      0         0       0         0
#
#    YOUTUBE  TIKTOK  EMAIL  OTHER
# 0        0       0      2      2
# 1        0       0      0      1
# 2        0       0      0      0
# 3        0       0      0     24
# 4        0       0      0    500

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('int64')]

# %%
df = df.select_dtypes(include = ['float64', 'int64'])
df.head()
# Out:
#    INTERN  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  SNAPCHAT  \
# 0       7         6          4        4      0         2       2         2
# 1       9       120          2        0      0         3       2         1
# 2      10         0          0        0      0         0       0         0
# 3      15         0         48      294      0        10      76        26
# 4      18       840        186        0      0         0       0         0
#
#    YOUTUBE  TIKTOK  EMAIL  OTHER
# 0        0       0      2      2
# 1        0       0      0      1
# 2        0       0      0      0
# 3        0       0      0     24
# 4        0       0      0    500

# %%
df.shape
# Out:
# (46, 12)

# %%
print(df.isnull().sum())
# Out:
# INTERN       0
# FACEBOOK     0
# INSTAGRAM    0
# TWITTER      0
# QUORA        0
# LINKEDIN     0
# REDDIT       0
# SNAPCHAT     0
# YOUTUBE      0
# TIKTOK       0
# EMAIL        0
# OTHER        0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# INTERN       46
# FACEBOOK     46
# INSTAGRAM    46
# TWITTER      46
# QUORA        46
# LINKEDIN     46
# REDDIT       46
# SNAPCHAT     46
# YOUTUBE      46
# TIKTOK       46
# EMAIL        46
# OTHER        46
# dtype: int64

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 12)

# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

plt.style.use('bmh')

df = pd.read_csv('C://Users//NITHIN SYLESH//Documents//int//onepercent//New folder//CSV Files//DIGITAL_MARKETING_PLATFORM_DATE_GOOGLE.csv')
df.head()

list(set(df.dtypes.tolist()))

df = df.select_dtypes(include = ['float64', 'int64'])
df.head()

df.shape

print(df.isnull().sum())

duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)

plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# FACEBOOK     0
# INSTAGRAM    0
# TWITTER      0
# QUORA        0
# LINKEDIN     0
# REDDIT       0
# SNAPCHAT     0
# YOUTUBE      0
# TIKTOK       0
# EMAIL        0
# OTHER        0
# dtype: int64
# number of duplicate rows:  (10, 11)
#            FACEBOOK  INSTAGRAM   TWITTER     QUORA  LINKEDIN    REDDIT  \
# FACEBOOK   1.000000   0.116669  0.247957  0.145622  0.350305  0.070024
# INSTAGRAM  0.116669   1.000000 -0.005225  0.114176  0.132120 -0.057335
# TWITTER    0.247957  -0.005225  1.000000  0.069605  0.309374  0.060311
# QUORA      0.145622   0.114176  0.069605  1.000000  0.249191 -0.102679
# LINKEDIN   0.350305   0.132120  0.309374  0.249191  1.000000  0.123249
# REDDIT     0.070024  -0.057335  0.060311 -0.102679  0.123249  1.000000
# SNAPCHAT   0.094933  -0.022520  0.137514 -0.091947  0.077111 -0.030541
# YOUTUBE    0.363940   0.320369  0.168443  0.285538  0.379245 -0.175023
# TIKTOK          NaN        NaN       NaN       NaN       NaN       NaN
# ...
