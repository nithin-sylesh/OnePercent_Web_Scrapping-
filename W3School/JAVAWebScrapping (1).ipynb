# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen

from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.w3schools.com/java/default.asp"

# Lets make a request to "https://www.w3schools.com/html/default.asp"
# Will store the result in 'res' variable
page = requests.get(url)

txt = page.text
status = page.status_code

# %%
#printing the staus of the requests
print(status)
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# creating a list of all common heading tags
heading_tags = ["h1","h2","h3"]
for tags in soup.find_all(heading_tags):
    print(tags.name + ' -> ' + tags.text.strip())
# Out:
# h2 -> Tutorials
# h3 -> HTML and CSS
# h3 -> Data Analytics
# h3 -> XML Tutorials
# h3 -> JavaScript
# h3 -> Programming
# h3 -> Server Side
# h3 -> Web Building
# h3 -> Data Analytics
# h3 -> XML Tutorials
# h2 -> References
# h3 -> HTML
# h3 -> CSS
# h3 -> JavaScript
# h3 -> Programming
# h3 -> Server Side
# h3 -> XML
# h3 -> Character Sets
# h2 -> Exercises and Quizzes
# h3 -> Exercises
# h3 -> Quizzes
# h3 -> Courses
# h3 -> Certificates
# h2 -> Java Tutorial
# h2 -> Java Methods
# h2 -> Java Classes
# h2 -> Java File Handling
# h2 -> Java How To
# h2 -> Java Reference
# h2 -> Java Examples
# h1 -> Java Tutorial
# h2 -> Examples in Each Chapter
# h3 -> Example
# h2 -> Java Exercises
# h2 -> Test Yourself With Exercises
# h2 -> Exercise:
# h2 -> Java Quiz
# h2 -> Learn by Examples
# h2 -> Java Reference
# h2 -> Download Java
# h2 -> Kickstart your career
# h2 -> Report Error
# h2 -> Thank You For Helping Us!

# %%
heading1 = soup.find_all('h2', class_ = 'left')
heading1
# Out:
# [<h2 class="left"><span class="left_h2">Java</span> Tutorial</h2>]

# %%
sub_headings = []
for i in heading1:
    print(i.text)
    sub_headings.append(i.text)
# Out:
# Java Tutorial

# %%
# contents in html
heading2 = soup.find_all('a', target='_top')
heading2
# Out:
# [<a class="w3-bar-item w3-button" href="/html/html_quiz.asp" target="_top">HTML Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/css/css_quiz.asp" target="_top">CSS Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/js/js_quiz.asp" target="_top">JavaScript Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/sql/sql_quiz.asp" target="_top">SQL Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/mysql/mysql_quiz.asp" target="_top">MySQL Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/php/php_quiz.asp" target="_top">PHP Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/python/python_quiz.asp" target="_top">Python Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/python/numpy/numpy_quiz.asp" target="_top">NumPy Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/python/pandas/pandas_quiz.asp" target="_top">Pandas Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/python/scipy/scipy_quiz.php" target="_top">SciPy Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/jquery/jquery_quiz.asp" target="_top">jQuery Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/java/java_quiz.asp" target="_top">Java Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/cpp/cpp_quiz.asp" target="_top">C++ Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/cs/cs_quiz.asp" target="_top">C# Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/r/r_quiz.asp" target="_top">R Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/xml/xml_quiz.asp" target="_top">XML Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/bootstrap/bootstrap_quiz.asp" target="_top">Bootstrap Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/bootstrap4/bootstrap_quiz.asp" target="_top">Bootstrap 4 Quiz</a>,
#  <a class="w3-bar-item w3-button" href="/bootstrap5/bootstrap_quiz.php" target="_top">Bootstrap 5 Quiz</a>,
#  <a href="default.asp" target="_top">Java HOME</a>,
#  <a href="java_intro.asp" target="_top">Java Intro</a>,
#  <a href="java_getstarted.asp" target="_top">Java Get Started</a>,
#  <a href="java_syntax.asp" target="_top">Java Syntax</a>,
#  <a href="java_comments.asp" target="_top">Java Comments</a>,
#  <a href="java_variables.asp" target="_top">Java Variables</a>,
#  <a href="java_data_types.asp" target="_top">Java Data Types</a>,
#  <a href="java_type_casting.asp" target="_top">Java Type Casting</a>,
#  <a href="java_operators.asp" target="_top">Java Operators</a>,
#  <a href="java_strings.asp" target="_top">Java Strings</a>,
#  <a href="java_math.asp" target="_top">Java Math</a>,
#  <a href="java_booleans.asp" target="_top">Java Booleans</a>,
#  <a href="java_conditions.asp" target="_top">Java If...Else</a>,
#  <a href="java_switch.asp" target="_top">Java Switch</a>,
#  <a href="java_while_loop.asp" target="_top">Java While Loop</a>,
#  <a href="java_for_loop.asp" target="_top">Java For Loop</a>,
#  <a href="java_break.asp" target="_top">Java Break/Continue</a>,
#  <a href="java_arrays.asp" target="_top">Java Arrays</a>,
#  <a href="java_methods.asp" target="_top">Java Methods</a>,
#  <a href="java_methods_param.asp" target="_top">Java Method Parameters</a>,
#  <a href="java_methods_overloading.asp" target="_top">Java Method Overloading</a>,
#  <a href="java_scope.asp" target="_top">Java Scope</a>,
#  <a href="java_recursion.asp" target="_top">Java Recursion</a>,
#  <a href="java_oop.asp" target="_top">Java OOP</a>,
#  <a href="java_classes.asp" target="_top">Java Classes/Objects</a>,
#  <a href="java_class_attributes.asp" target="_top">Java Class Attributes</a>,
#  <a href="java_class_methods.asp" target="_top">Java Class Methods</a>,
#  <a href="java_constructors.asp" target="_top">Java Constructors</a>,
#  <a href="java_modifiers.asp" target="_top">Java Modifiers</a>,
#  <a href="java_encapsulation.asp" target="_top">Java Encapsulation</a>,
#  <a href="java_packages.asp" target="_top">Java Packages / API</a>,
#  <a href="java_inheritance.asp" target="_top">Java Inheritance</a>,
#  <a href="java_polymorphism.asp" target="_top">Java Polymorphism</a>,
#  <a href="java_inner_classes.asp" target="_top">Java Inner Classes</a>,
#  <a href="java_abstract.asp" target="_top">Java Abstraction</a>,
#  <a href="java_interface.asp" target="_top">Java Interface</a>,
#  <a href="java_enums.asp" target="_top">Java Enums</a>,
#  <a href="java_user_input.asp" target="_top">Java User Input</a>,
#  <a href="java_date.asp" target="_top">Java Date</a>,
#  <a href="java_arraylist.asp" target="_top">Java ArrayList</a>,
#  <a href="java_linkedlist.asp" target="_top">Java LinkedList</a>,
#  <a href="java_hashmap.asp" target="_top">Java HashMap</a>,
#  <a href="java_hashset.asp" target="_top">Java HashSet</a>,
#  <a href="java_iterator.asp" target="_top">Java Iterator</a>,
#  <a href="java_wrapper_classes.asp" target="_top">Java Wrapper Classes</a>,
#  <a href="java_try_catch.asp" target="_top">Java Exceptions</a>,
#  <a href="java_regex.asp" target="_top">Java RegEx</a>,
#  <a href="java_threads.asp" target="_top">Java Threads</a>,
#  <a href="java_lambda.asp" target="_top">Java Lambda</a>,
#  <a href="java_files.asp" target="_top">Java Files</a>,
#  <a href="java_files_create.asp" target="_top">Java Create/Write Files</a>,
#  <a href="java_files_read.asp" target="_top">Java Read Files</a>,
#  <a href="java_files_delete.asp" target="_top">Java Delete Files</a>,
#  <a href="java_howto_add_two_numbers.asp" target="_top">Add Two Numbers</a>,
#  <a href="java_ref_keywords.asp" target="_top">Java Keywords</a>,
#  <a href="ref_keyword_abstract.asp" target="_top">abstract</a>,
#  <a href="ref_keyword_boolean.asp" target="_top">boolean</a>,
#  <a href="ref_keyword_break.asp" target="_top">break</a>,
#  <a href="ref_keyword_byte.asp" target="_top">byte</a>,
#  <a href="ref_keyword_case.asp" target="_top">case</a>,
#  <a href="ref_keyword_catch.asp" target="_top">catch</a>,
#  <a href="ref_keyword_char.asp" target="_top">char</a>,
#  <a href="ref_keyword_class.asp" target="_top">class</a>,
#  <a href="ref_keyword_continue.asp" target="_top">continue</a>,
#  <a href="ref_keyword_default.asp" target="_top">default</a>,
#  <a href="ref_keyword_do.asp" target="_top">do</a>,
#  <a href="ref_keyword_double.asp" target="_top">double</a>,
#  <a href="ref_keyword_else.asp" target="_top">else</a>,
#  <a href="ref_keyword_enum.asp" target="_top">enum</a>,
#  <a href="ref_keyword_extends.asp" target="_top">extends</a>,
#  <a href="ref_keyword_final.asp" target="_top">final</a>,
#  <a href="ref_keyword_finally.asp" target="_top">finally</a>,
#  <a href="ref_keyword_float.asp" target="_top">float</a>,
#  <a href="ref_keyword_for.asp" target="_top">for</a>,
#  <a href="ref_keyword_if.asp" target="_top">if</a>,
#  <a href="ref_keyword_implements.asp" target="_top">implements</a>,
#  <a href="ref_keyword_import.asp" target="_top">import</a>,
#  <a href="ref_keyword_instanceof.asp" target="_top">instanceof</a>,
#  <a href="ref_keyword_int.asp" target="_top">int</a>,
#  <a href="ref_keyword_interface.asp" target="_top">interface</a>,
#  <a href="ref_keyword_long.asp" target="_top">long</a>,
#  <a href="ref_keyword_new.asp" target="_top">new</a>,
#  <a href="ref_keyword_package.asp" target="_top">package</a>,
#  <a href="ref_keyword_private.asp" target="_top">private</a>,
#  <a href="ref_keyword_protected.asp" target="_top">protected</a>,
#  <a href="ref_keyword_public.asp" target="_top">public</a>,
#  <a href="ref_keyword_return.asp" target="_top">return</a>,
#  <a href="ref_keyword_short.asp" target="_top">short</a>,
#  <a href="ref_keyword_static.asp" target="_top">static</a>,
#  <a href="ref_keyword_super.asp" target="_top">super</a>,
#  <a href="ref_keyword_switch.asp" target="_top">switch</a>,
#  <a href="ref_keyword_this.asp" target="_top">this</a>,
#  <a href="ref_keyword_throw.asp" target="_top">throw</a>,
#  <a href="ref_keyword_throws.asp" target="_top">throws</a>,
#  <a href="ref_keyword_try.asp" target="_top">try</a>,
#  <a href="ref_keyword_void.asp" target="_top">void</a>,
#  <a href="ref_keyword_while.asp" target="_top">while</a>,
#  <a href="java_ref_string.asp" target="_top">Java String Methods</a>,
#  <a href="java_ref_math.asp" target="_top">Java Math Methods</a>,
#  <a href="java_examples.asp" target="_top">Java Examples</a>,
#  <a href="java_compiler.asp" target="_top">Java Compiler</a>,
#  <a href="java_exercises.asp" target="_top">Java Exercises</a>,
#  <a href="java_quiz.asp" target="_top">Java Quiz</a>,
#  <a href="java_exam.asp" target="_top">Java Certificate</a>,
#  <a class="w3-button ws-grey w3-block w3-round" href="/about/default.asp" style="text-decoration:none;margin-top:1px;margin-bottom:1px;font-size:15px" target="_top">About</a>]

# %%
# getting the Headings, Sub-Headings, Links and Contents

# CREATING RELEVANT VARIABLES
tag = ''
page_table = []
course_heading = []
course_subheading = []
course_links = []
sub_page_content_list = []
unordered_lists = []
ordered_lists = []
list_headings = []
examples_per_page = []
excercises = []
base_url = "https://www.w3schools.com/java/"
course_url = "https://www.w3schools.com/java/"

# FINDING ALL THE LINKS PRESENT IN THE LEFT MENU AND ITERATING OVER THE LINKS TO SCRAPE THE DATA
test = soup.find('div', id='leftmenuinnerinner')

for i in test:
    if 'h2' in str(i):
        tag = i.text
    else:
        if (tag!='') and ('a href' in str(i)) and ('div class="tut_overview"' not in str(i)):
            course_heading.append(tag)
            course_subheading.append(i.text)
            extra = i.get('href')
           
            if extra is not None :
                print(extra)
                if extra[0] == '/':
                    base_url = "https://www.w3schools.com"
                    
            elif extra is None :
                continue 
           
                
                
            
            page_url = base_url + extra
            course_links.append(page_url)
            sub_page = requests.get(page_url)
            soup_page = BeautifulSoup(sub_page.content, 'html.parser')
            
            page_content = soup_page.find_all('div', class_ = 'w3-col l10 m12', id='main')
            page_examples = soup_page.find_all('div', class_ = 'w3-code notranslate javaHigh')
            
            ##################################################################################################
            
            # Examples per page
            pg_example = []
            for example in page_examples:
                nw = []
                for i in list(example):
                    if str(i) == '<br/>':
                        pass
                    else:
                        nw.append(i)
                pg_example.append(nw)
            examples_per_page.append(pg_example)
                
            ##################################################################################################
            
            # Search for tables 
            tables = soup_page.find_all('table')

            data = []
            for table in tables:
                all_rows = table.find_all('tr')
                for row in all_rows:
                    row_list = row.find_all('td')
                    dataRow = []
                    for cells in row_list:
                        dataRow.append(cells.text)
                    data.append(dataRow)

            table_new = []
            row = ''
            for i in range(1, len(data)):
                if len(data[i]) == 0:
                    row = row[:-3]
                    table_new.append(row) 
                    row = ''
                for j in data[i]:
                    row += j + "|||"
                    # using separator for each column
                row = row[:-3]
                # using '&&&' separator for each row
                row += '&&&'
                #print(row)
            row = row[:-3]
            if len(row) !=0:
                if row[0] == '&':
                    row = row[3:]
            table_new.append(row)
            table_string = ''
            for each in table_new:
                table_string += each + '$$$'
            table_new = table_string[:-3]
            page_table.append(table_new)
            
            ##################################################################################################
            
            # Points for Unordered lists
            ul = soup_page.find_all('ul')
            unorder = []
            for i in ul:
                start_string = ''
                for j in i:
                    if j.text != '\n':
                        #print(j.text.replace('\n',''))
                        start_string += j.text.replace('\n','') + '@@@'
                start_string = start_string[:-3]
                unorder.append(start_string)
            if len(unorder) == 0:
                unorder = None
            else:
                unorder_string = ''
                for i in unorder:
                    unorder_string += i +'|||'
                unorder = unorder_string[:-3]
            unordered_lists.append(unorder)
            
                        
            ##################################################################################################
            #Points for ordered list.
            ol = soup_page.find_all('ol')
            order = []
            for i in ol:
                start_string = ''
                for j in i:
                    if j.text != '\n':
                        #print(j.text.replace('\n',''))
                        start_string += j.text.replace('\n','') + '@@@'
                start_string = start_string[:-3]
                order.append(start_string)
            
            if len(order) == 0:
                order = None
            else:
                order_string = ''
                for i in order:
                    order_string += i +'|||'
                order = order_string[:-3]
            ordered_lists.append(order)
            
            ##################################################################################################
            
            # Headings and Subheadings and Description
            
            list_headings_per_page = []
            for page_data in page_content:
                for j in str(page_data).split('\n'):
                    list_headings_per_page.append(j)
                page_paragraphs = page_data.find_all('p')
        
            content_per_page = ''
            for i in page_paragraphs:
                content_per_page += i.text + '|||'
            content_per_page = content_per_page[:-3].replace('\n', '')
            sub_page_content_list.append(content_per_page)
            
            prev = ''
            ul_ol_heading = ''
            for i in list_headings_per_page:
                if ('ul' in i) and (('h2' in prev) or ('h3' in prev)):
                    ul_ol_heading += prev[4:-5] + '|||'
                prev = i
            list_headings.append(ul_ol_heading[:-3])
#             time.sleep(5)
# Out:
# default.asp
# java_intro.asp
# java_getstarted.asp
# java_syntax.asp
# java_comments.asp
# java_variables.asp
# java_data_types.asp
# java_type_casting.asp
# java_operators.asp
# java_strings.asp
# java_math.asp
# java_booleans.asp
# java_conditions.asp
# java_switch.asp
# java_while_loop.asp
# java_for_loop.asp
# java_break.asp
# java_arrays.asp
# java_methods.asp
# java_methods_param.asp
# java_methods_overloading.asp
# java_scope.asp
# java_recursion.asp
# java_oop.asp
# java_classes.asp
# java_class_attributes.asp
# java_class_methods.asp
# java_constructors.asp
# java_modifiers.asp
# java_encapsulation.asp
# java_packages.asp
# java_inheritance.asp
# java_polymorphism.asp
# java_inner_classes.asp
# java_abstract.asp
# java_interface.asp
# java_enums.asp
# java_user_input.asp
# java_date.asp
# java_arraylist.asp
# java_linkedlist.asp
# java_hashmap.asp
# java_hashset.asp
# java_iterator.asp
# java_wrapper_classes.asp
# java_try_catch.asp
# java_regex.asp
# java_threads.asp
# java_lambda.asp
# java_files.asp
# java_files_create.asp
# java_files_read.asp
# java_files_delete.asp
# java_howto_add_two_numbers.asp
# java_ref_keywords.asp
# java_ref_string.asp
# java_ref_math.asp
# java_examples.asp
# java_compiler.asp
# java_exercises.asp
# java_quiz.asp
# java_exam.asp

# %%
length = len(course_links)
length
# Out:
# 62

# %%
len(course_heading), len(course_subheading), len(course_links), len(sub_page_content_list), len(list_headings), len(unordered_lists),len(ordered_lists),  len(page_table), len(examples_per_page)
# Out:
# (63, 63, 62, 62, 62, 62, 62, 62, 62)

# %%
from csv import writer

# writing the file
with open('java_w3school.csv', 'w', encoding='utf8', newline='') as f:
    the_writer = writer(f)
    header = ['Heading', 'Sub-Heading', 'Links', 'Description','List Headings', 
              'Unordered Lists', 'Ordered Lists','Table Data', 'Examples']
    the_writer.writerow(header)
    for i in range(length):
        row = [course_heading[i], course_subheading[i], course_links[i], sub_page_content_list[i], list_headings[i], 
               unordered_lists[i], ordered_lists[i], page_table[i], examples_per_page[i]]
        the_writer.writerow(row)

# reading the file
file = pd.read_csv('java_w3school.csv')
dataset = pd.DataFrame(file)

# viewing first 5 rows
dataset.head(5)
# Out:
#          Heading       Sub-Heading  \
# 0  Java Tutorial         Java HOME
# 1  Java Tutorial        Java Intro
# 2  Java Tutorial  Java Get Started
# 3  Java Tutorial       Java Syntax
# 4  Java Tutorial     Java Comments
#
#                                                Links  \
# 0         https://www.w3schools.com/java/default.asp
# 1      https://www.w3schools.com/java/java_intro.asp
# 2  https://www.w3schools.com/java/java_getstarted...
# 3     https://www.w3schools.com/java/java_syntax.asp
# 4   https://www.w3schools.com/java/java_comments.asp
#
#                                          Description  \
# 0  Java is a popular programming language.|||Java...
# 1  Java is a popular programming language, create...
# 2  Some PCs might have Java already installed.|||...
# 3  In the previous chapter, we created a Java fil...
# 4  Comments can be used to explain Java code, and...
#
#                    List Headings  \
# 0       Examples in Each Chapter
# 1  What is Java?|||Why Use Java?
# 2                            NaN
# 3                            NaN
# 4       Java Multi-line Comments
#
#                                      Unordered Lists  \
# 0                                                NaN
# 1  Mobile applications (specially Android apps)@@...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Ordered Lists Table Data Examples
# 0                                                NaN        NaN       []
# 1                                                NaN        NaN       []
# 2  Go to "System Properties" (Can be found on Con...        NaN       []
# 3                                                NaN        NaN       []
# 4                                                NaN        NaN       []

# %%
# Re-checking the dataset and removing cells that have no relevant data
for i in range(len(dataset['Table Data'])):
    try:
        if len(dataset['Table Data'][i]) == 4:
            dataset['Table Data'][i] = None
        if len(dataset['Examples'][i]) == 2:
            dataset['Examples'][i] = None
    except TypeError:
        pass

# %%
# Removing the Null values and keeping the cells empty
dataset = dataset.replace(np.nan, '', regex=True)

# %%
# Making a separate column for those heading which are not associated with the Lists
new_col = [None for i in range(len(course_links))]
dataset['Other Headings'] = pd.Series(new_col)
for i in range(len(dataset['Unordered Lists'])):
    if dataset['Unordered Lists'][i] == '':
        dataset['Other Headings'][i] = dataset['List Headings'][i]
        dataset['List Headings'][i] = ''

# %%
# Removing the Null values and keeping the cells empty
dataset = dataset.replace(np.nan, '', regex=True)

# %%
# viewing the top 10 rows
dataset.head(10)
# Out:
#          Heading        Sub-Heading  \
# 0  Java Tutorial          Java HOME
# 1  Java Tutorial         Java Intro
# 2  Java Tutorial   Java Get Started
# 3  Java Tutorial        Java Syntax
# 4  Java Tutorial      Java Comments
# 5  Java Tutorial     Java Variables
# 6  Java Tutorial    Java Data Types
# 7  Java Tutorial  Java Type Casting
# 8  Java Tutorial     Java Operators
# 9  Java Tutorial       Java Strings
#
#                                                Links  \
# 0         https://www.w3schools.com/java/default.asp
# 1      https://www.w3schools.com/java/java_intro.asp
# 2  https://www.w3schools.com/java/java_getstarted...
# 3     https://www.w3schools.com/java/java_syntax.asp
# 4   https://www.w3schools.com/java/java_comments.asp
# 5  https://www.w3schools.com/java/java_variables.asp
# 6  https://www.w3schools.com/java/java_data_types...
# 7  https://www.w3schools.com/java/java_type_casti...
# 8  https://www.w3schools.com/java/java_operators.asp
# 9    https://www.w3schools.com/java/java_strings.asp
#
#                                          Description  \
# 0  Java is a popular programming language.|||Java...
# 1  Java is a popular programming language, create...
# 2  Some PCs might have Java already installed.|||...
# 3  In the previous chapter, we created a Java fil...
# 4  Comments can be used to explain Java code, and...
# 5  Variables are containers for storing data valu...
# 6  As explained in the previous chapter, a variab...
# 7  Type casting is when you assign a value of one...
# 8  Operators are used to perform operations on va...
# 9  Strings are used for storing text.|||A String ...
#
#                                   List Headings  \
# 0
# 1                 What is Java?|||Why Use Java?
# 2
# 3
# 4
# 5
# 6  Long|||Floating Point Types|||Float|||Double
# 7
# 8                                     Exercise:
# 9
#
#                                      Unordered Lists  \
# 0
# 1  Mobile applications (specially Android apps)@@...
# 2
# 3
# 4
# 5  String - stores text, such as "Hello". String ...
# 6  Primitive data types - includes byte, short, i...
# 7  Widening Casting (automatically) - converting ...
# 8  Arithmetic operators@@@Assignment operators@@@...
# 9
#
#                                        Ordered Lists  \
# 0
# 1
# 2  Go to "System Properties" (Can be found on Con...
# 3
# 4
# 5
# 6
# 7
# 8
# 9
#
#                                           Table Data Examples  \
# 0                                                          []
# 1                                                          []
# 2                                                          []
# 3                                                          []
# 4                                                          []
# 5                                                          []
# 6  byte|||1 byte|||Stores whole numbers from -128...
# 7                                                          []
# 8  +|||Addition|||Adds together two values|||x + ...
# 9  \'|||'|||Single quote&&&\"|||"|||Double quote&...
#
#              Other Headings
# 0  Examples in Each Chapter
# 1
# 2
# 3
# 4  Java Multi-line Comments
# 5
# 6
# 7
# 8
# 9
